# %%
from convokit import Corpus, download
import pandas as pd
# from convokit import Corpus, download

awry_corpus = Corpus(filename="C:/Users/L/.convokit/downloads/conversations-gone-awry-cmv-corpus")
# corpus = Corpus(filename="C:/Users/L/.convokit/downloads/subreddit-AmericanPolitics")
awry_corpus.print_summary_stats()
awry_corpus.load_info('utterance',['parsed'])
# Out:
# Number of Speakers: 9548
# Number of Utterances: 42964
# Number of Conversations: 6842
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 # corpus = Corpus(filename="C:/Users/L/.convokit/downloads/subreddit-AmericanPolitics")
#       7 awry_corpus.print_summary_stats()
# ----> 8 awry_corpus.load_info('utterance',['parsed'])
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\corpus.py:1304, in Corpus.load_info(self, obj_type, fields, dir_name)
#    1300 for field in fields:
#    1301     # self.aux_info[field] = self.load_jsonlist_to_dict(
#    1302     #     os.path.join(dir_name, 'feat.%s.jsonl' % field))
#    1303     if self.backend == "mem":
# -> 1304         load_info_to_mem(self, dir_name, obj_type, field)
#    1305     elif self.backend == "db":
#    1306         load_info_to_db(self, dir_name, obj_type, field)
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\corpus_helpers.py:807, in load_info_to_mem(corpus, dir_name, obj_type, field)
#     801 """
#     802 Helper for load_info in mem mode that reads the file for the specified extra
#     803 info field, loads it into memory, and assigns the entries to their
#     804 corresponding corpus components.
#     805 """
#     806 getter = lambda oid: corpus.get_object(obj_type, oid)
# --> 807 entries = load_jsonlist_to_dict(os.path.join(dir_name, "info.%s.jsonl" % field))
#     808 for k, v in entries.items():
#     809     try:
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\corpus_helpers.py:594, in load_jsonlist_to_dict(filename, index_key, value_key)
#     592 def load_jsonlist_to_dict(filename, index_key="id", value_key="value"):
#     593     entries = {}
# --> 594     with open(filename, "r") as f:
#     595         for line in f:
#     596             entry = json.loads(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/L/.convokit/downloads/conversations-gone-awry-cmv-corpus\\info.parsed.jsonl'

# %%
import os

import numpy as np
import pandas as pd
from scipy import stats

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, LeaveOneGroupOut
from sklearn.feature_selection import f_classif, SelectPercentile

from collections import defaultdict
from functools import partial
from multiprocessing import Pool

from convokit import download
from convokit.prompt_types import PromptTypeWrapper
from convokit import PolitenessStrategies
from convokit import Corpus

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
awry_corpus = awry_corpus.filter_conversations_by(lambda convo: convo.meta['annotation_year'] == '2018')
awry_corpus.print_summary_stats()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 awry_corpus = awry_corpus.filter_conversations_by(lambda convo: convo.meta['annotation_year'] == '2018')
#       2 awry_corpus.print_summary_stats()
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\corpus.py:607, in Corpus.filter_conversations_by(self, selector)
#     599 def filter_conversations_by(self, selector: Callable[[Conversation], bool]):
#     600     """
#     601     Mutate the corpus by filtering for a subset of Conversations within the Corpus.
#     602
#     603     :param selector: function for selecting which Conversations to keep
#     604     :return: the mutated Corpus
#     605     """
# --> 607     self.conversations = {
#     608         convo_id: convo for convo_id, convo in self.conversations.items() if selector(convo)
#     609     }
#     610     utt_ids = set(
#     611         [utt for convo in self.conversations.values() for utt in convo.get_utterance_ids()]
#     612     )
#     613     self.utterances = {utt.id: utt for utt in self.utterances.values() if utt.id in utt_ids}
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\corpus.py:608, in <dictcomp>(.0)
#     599 def filter_conversations_by(self, selector: Callable[[Conversation], bool]):
#     600     """
#     601     Mutate the corpus by filtering for a subset of Conversations within the Corpus.
#     602
#     603     :param selector: function for selecting which Conversations to keep
#     604     :return: the mutated Corpus
#     605     """
#     607     self.conversations = {
# --> 608         convo_id: convo for convo_id, convo in self.conversations.items() if selector(convo)
#     609     }
#     610     utt_ids = set(
#     611         [utt for convo in self.conversations.values() for utt in convo.get_utterance_ids()]
#     612     )
#     613     self.utterances = {utt.id: utt for utt in self.utterances.values() if utt.id in utt_ids}
#
# Cell In[4], line 1, in <lambda>(convo)
# ----> 1 awry_corpus = awry_corpus.filter_conversations_by(lambda convo: convo.meta['annotation_year'] == '2018')
#       2 awry_corpus.print_summary_stats()
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\convoKitMeta.py:37, in ConvoKitMeta.__getitem__(self, item)
#      33 def __getitem__(self, item):
#      34     # in DB mode, metadata field mutation would not be updated. (ex. mutating dict/list metadata fields)
#      35     # we align MEM mode behavior and DB mode by making deepcopy of metadata fields, so mutation no longer
#      36     # affect corpus metadata backend, but only acting on the copy of it.
# ---> 37     item = self._get_backend().get_data(
#      38         "meta", self.backend_key, item, self.index.get_index(self.obj_type)
#      39     )
#      40     immutable_types = (int, float, bool, complex, str, tuple, frozenset)
#      41     if isinstance(item, immutable_types):
#
# File ~\anaconda3\envs\Raja\Lib\site-packages\convokit\model\backendMapper.py:179, in MemMapper.get_data(self, component_type, component_id, property_name, index)
#     177     return collection[component_id]
#     178 else:
# --> 179     return collection[component_id][property_name]
#
# KeyError: 'annotation_year'
