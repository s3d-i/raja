# %%
from utils import *
dfls = read_df_list('combat_df_list_imms_1_full_perspective_list_moreRefuse_refuseCleaned.pkl')
dfls=flatten_df_list(dfls)

# %%
check_column_type(dfls[0])
# Out:
# text <class 'str'>
# imm_1 <class 'str'>
# imm_1_check <class 'numpy.bool_'>
# perspective <class 'dict'>
# perspective_type <class 'type'>
# perspective_ls <class 'list'>
# refuse_add <class 'list'>
# true_rate <class 'numpy.float64'>

# %%
from utils import *
print(sentence_immitation_stream(dfls[0]['text'].values[0], temperature=0))
# Out:
# {"--IMMITATION--": "Research into identical twins reveals that roughly three-quarters of the differences in intelligence quotient can be attributed to inherited traits."}

# %%
# del chat_immitation_stream
# from utils import chat_immitation_stream
print(chat_immitation_stream(dfls[0]['text'].values[0], temperature=0))
# Out:
# OUTPUT FORMAT:
# {"--IMMITATION--": YOUR_IMMITATION_TEXTS}
#
# Your immitation should preserve the Speaker's semantic meaning and emotions sentence by sentence.

# %%
print(completion_immitation_stream(dfls[0]['text'].values[0], temperature=0))
# Out:
#  This means that if you have a sibling with a high IQ, you are more likely to have a high IQ as well. This is because you share
